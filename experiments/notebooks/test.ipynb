# %% [markdown]
# # validate shapes of activations

# %%
import pandas as pd



x = pd.read_pickle("/rds/general/user/nk1924/home/ign-inf-unlearning/data/activations/gibberish/layer_30.pkl")

# %%
x[0].shape
# Out:
# torch.Size([69, 2560])

# %%
print(f"Number of examples: {len(x)}")  # Should be 811
print(f"First example shape: {x[0].shape}")  # [69, 2560]
print(f"Second example shape: {x[1].shape}")  # Probably different seq length
print(f"Last example shape: {x[-1].shape}")  # Also probably different
# Out:
# Number of examples: 811
# First example shape: torch.Size([69, 2560])
# Second example shape: torch.Size([69, 2560])
# Last example shape: torch.Size([27, 2560])

# %%
csv = pd.read_csv("/rds/general/user/nk1924/home/ign-inf-unlearning/data/datasets/input_data/wmdp-bio-forget-mcqa/gibberish.csv")

# %%
len(csv)
# Out:
# 811

# %%
len(csv)
# Out:
# 811
